# %% [markdown]
# # 02 - Model Experiments
#
# Scratch space for comparing Tier 1 (EfficientNet-B0) hyperparameters and Tier 3 (CLIP probe) regularization before locking in the settings used in `src/model/train.py` / `src/semantic/train_probe.py`.

# %%
import sys
sys.path.insert(0, '..')
from src.model.model import Tier1CNN, build_transform
from src.semantic.embed import ClipEmbedder

# %% [markdown]
# ## Tier 1 sweep
#
# Track val AUC across learning rate / epoch count here before committing to defaults in `src/model/train.py`.

# %% [markdown]
# ## Tier 3 probe sweep
#
# Compare LogisticRegression vs. a small MLP head on frozen CLIP embeddings.
